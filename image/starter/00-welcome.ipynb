# %% [markdown]
# # Welcome to NST Jupyter Platform 👋
#
# This notebook runs on the **NST Compute Cluster**.
#
# Each notebook server is:
# - isolated
# - ephemeral
# - scheduled on available compute nodes
#
# 👉 **Your work is NOT saved here permanently.**
# You are expected to use **GitHub for version control**.

# %% [markdown]
# ## How to use this environment
#
# ### 0. Login (recommended):
# ```bash
# gh auth login
# ```
#
# ### 1. Clone your own notebook repository
# ```bash
# git clone https://github.com/<your-username>/your-notebooks.git
# cd your-notebooks
# ```
#
# ### 2. Work inside your repo
# - Create notebooks
# - Run experiments
# - Commit often
#
# ### 3. Commit + push:
# ```bash
# git add .
# git commit -m "update"
# git push
# ```

# %%
print("Your environment is ready. 🚀")

# %% [markdown]
# ## Important links (read these)
#
# - JupyterLab docs: https://jupyterlab.readthedocs.io
# - Git basics: https://git-scm.com/docs/gittutorial
# - Python docs: https://docs.python.org/3/
# - NumPy: https://numpy.org/doc/
# - Pandas: https://pandas.pydata.org/docs/
# - GitHub CLI: https://cli.github.com/
#
# (Do not rely on memory. Learn to read docs.)
